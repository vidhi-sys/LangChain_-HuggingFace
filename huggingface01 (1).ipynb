# %%
#!pip install transformers
#!pip install accelerate
#!pip install bitsandbytes
#!pip install --upgrade huggingface_hub
#!pip install langchain-huggingface
#!pip install langchain-community

# %%
from google.colab import userdata
secret_key=userdata.get('test')

# %%
#!pip install langchain-community

# %%
from langchain_community.llms import HuggingFaceHub
import os
os.environ['test'] = secret_key

# %%
#!pip install -U langchain-huggingface
from langchain_huggingface import HuggingFaceEndpoint

# %%
from langchain_community.llms import HuggingFaceHub
import os

os.environ['test'] = secret_key

repo_id = "mistralai/Mistral-7B-Instruct-v0.2"
llm = HuggingFaceHub(
    repo_id=repo_id,
    model_kwargs={
        "temperature": 0.7,
        "max_length": 128,
        "task": "text-generation"
    }
)

# %%
from langchain import PromptTemplate, LLMChain
question = "who won cricket worldcup in year 2011 "
template="""Question:{question}
Answer: Let's think step by step"""
prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt.format(question=question))
# Out:
# Question:who won cricket worldcup in year 2011
# Answer: Let's think step by step

# %%
llm_chain = LLMChain(prompt=prompt, llm=llm)
print(llm_chain.invoke(question))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1788609148.py in <cell line: 0>()
#       1 llm_chain = LLMChain(prompt=prompt, llm=llm)
# ----> 2 print(llm_chain.invoke(question))
#
# /usr/local/lib/python3.12/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     163             self._validate_inputs(inputs)
#     164             outputs = (
# --> 165                 self._call(inputs, run_manager=run_manager)
#     166                 if new_arg_supported
#     167                 else self._call(inputs)
#
# /usr/local/lib/python3.12/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#     125         run_manager: Optional[CallbackManagerForChainRun] = None,
#     126     ) -> dict[str, str]:
# --> 127         response = self.generate([inputs], run_manager=run_manager)
# ...

# %% [markdown]
# # **PipeLines**

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoTokenizer, pipeline, AutoModelForCausalLM
import torch

# %%
model_id="gpt2"
my_model=AutoModelForCausalLM.from_pretrained(model_id)
tokenizer=AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
pipe=pipeline(task="text-generation",model=my_model, tokenizer=tokenizer)
# Out:
# Device set to use cpu

# %%
hf=HuggingFacePipeline(pipeline=pipe)

# %%
hf.invoke("spiderman is my favourite movie because")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...
